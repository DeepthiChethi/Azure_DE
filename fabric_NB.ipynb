# %%
# Welcome to your new notebook
# Type here in the cell editor to add code!
df = spark.read.format("csv").option("header",True).option("inferschema",True).load("Files/Credit.csv")
display(df)
# Out:
# StatementMeta(, f88d534c-0cea-42a1-8271-2f832e164e44, 3, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 5591af47-809b-4175-ad9f-f53fc968936e)

# %%
import com.microsoft.spark.fabric
from com.microsoft.spark.fabric.Constants import Constants
# Out:
# StatementMeta(, f88d534c-0cea-42a1-8271-2f832e164e44, 5, Finished, Available, Finished)

# %%
df.write.mode("append").synapsesql("warehouse_fabric.dbo.Credit1")
# Out:
# StatementMeta(, f88d534c-0cea-42a1-8271-2f832e164e44, 17, Finished, Available, Finished)

# %% [markdown]
# ### **Read data from warehouse and load data to lakehouse**

# %%
df_warehosue = spark.read.synapsesql("warehouse_fabric.dbo.Customer")
display(df_warehosue)
# Out:
# StatementMeta(, f88d534c-0cea-42a1-8271-2f832e164e44, 18, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 73c51794-6e3e-489c-a34c-cf94ee9ba585)

# %%
df_warehosue.write.format("csv").option("header",True).mode("append").save("Files/new_data.csv")
# Out:
# StatementMeta(, f88d534c-0cea-42a1-8271-2f832e164e44, 21, Finished, Available, Finished)
